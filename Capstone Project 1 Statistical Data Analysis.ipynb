# %% [markdown]
# ## Capstone Project 1
# ## Statistical Data Analysis
# ### Federico Di Martino
#
# #### Performing Statistical Data Analysis on Bank Customer Churn Data
#
# #### Answering the following questions
# - Are there variables that are particularly significant in terms of explaining the answer to your project question?
# - Are there significant differences between subgroups in your data that may be relevant to your project aim?
# - Are there strong correlations between pairs of independent variables or between an independent and a dependent variable?
# - What are the most appropriate tests to use to analyze these relationships?
#
#
#
# ### Preliminary Actions

# %%
## Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

## Import data
churn_data = pd.read_csv("Churn_Modelling.csv", index_col = 0)

## Print head to show structure of data
print(churn_data.head())
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
## Generate correlation matrix in same way that was done for data story segment

## To work, all values need to be numeric
# churn_data.fillna(value=np.nan, inplace=True)
## reshape data so that geography column becomes three binary columns
heatmap_data = churn_data
heatmap_data['IsFrance'] = 0
heatmap_data['IsSpain'] = 0
heatmap_data['IsGermany'] = 0

heatmap_data.loc[heatmap_data['Geography'] == 'France','IsFrance'] = 1
heatmap_data.loc[heatmap_data['Geography'] == 'Spain','IsSpain'] = 1
heatmap_data.loc[heatmap_data['Geography'] == 'Germany','IsGermany'] = 1

heatmap_data['IsFrance'] = pd.to_numeric(heatmap_data['IsFrance'])
heatmap_data['IsSpain'] = pd.to_numeric(heatmap_data['IsSpain'])
heatmap_data['IsGermany'] = pd.to_numeric(heatmap_data['IsGermany'])

## Change gender column such that female -> 1, male -> 0
heatmap_data.loc[heatmap_data['Gender'] == 'Female','Gender'] = 1
heatmap_data.loc[heatmap_data['Gender'] == 'Male','Gender'] = 0
heatmap_data["Gender"] = pd.to_numeric(heatmap_data["Gender"])


# Drop columns not be used
heatmap_data = heatmap_data.drop(['CustomerId', 'Surname', 'Geography'], axis = 'columns')


# Calculate correlations
corr = heatmap_data.corr()

# Visualise correlation matrix
corr.style.background_gradient(cmap='coolwarm', axis = None).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col1 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col2 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col3 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col4 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col5 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col6 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col7 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col8 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col9 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col10 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col11 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow0_col12 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col0 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col2 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col3 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col4 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col5 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col6 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col7 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col8 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col9 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col10 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col11 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow1_col12 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col0 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col1 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col3 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col4 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col5 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col6 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col7 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col8 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col9 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col10 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col11 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow2_col12 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col0 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col1 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col2 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col4 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col5 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col6 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col7 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col8 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col9 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col10 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col11 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow3_col12 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow4_col0 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow4_col1 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow4_col2 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow4_col3 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow4_col5 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow4_col6 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_bbe3101c_2a5c_11ea_bb51_f4d10856ff7brow4_col7 {
#             background-color:  #b3cdfb;
#             color:

# %% [markdown]
# ### Are there variables that are particularly significant in terms of explaining the answer to your project question?
#
# The project aims to predict the likelihood of a customer churning (Exited =1 in the data).  Hence the particularly significant variables are the ones that correlate the most with Exited. Although there are no extremely strong correlations, the Gender, Age, Balance, IsActiveMember and IsGermany variables are the ones that show most correlation and should be investigated the most.
#
# ### Are there significant differences between subgroups in your data that may be relevant to your project aim?
# The variables for customer gender, activity and nationality denote distinct subgroups. They are represented by variables that I think are signficant, as above.
#
# ### Are there strong correlations between pairs of independent variables or between an independent and a dependent variable?
# There aren't any strong (coefficient magnitude > 0.8) correlations per se. The strongest ones are, apart from the ones relating to Exited detailed above, the ones relating balance to the number of products and to nationality.
#
# ### What are the most appropriate tests to use to analyze these relationships?
# The test I used to analyze this relationship was using the Pearson product-moment method.
